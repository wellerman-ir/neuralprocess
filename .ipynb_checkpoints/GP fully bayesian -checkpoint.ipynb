# %%
import math
import torch
import gpytorch
import pyro
from pyro.infer.mcmc import NUTS, MCMC, HMC
from matplotlib import pyplot as plt

# %%
# Training data is 11 points in [0,1] inclusive regularly spaced
train_x = torch.linspace(0, 1, 4)
# True function is sin(2*pi*x) with Gaussian noise
train_y = torch.sin(train_x * (2 * math.pi)) + torch.randn(train_x.size()) * 0.2

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())

    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %% [markdown]
# ### running samples

# %%
# this is for running the notebook in our testing framework
import os
smoke_test = ('CI' in os.environ)
num_samples = 2 if smoke_test else 100
warmup_steps = 2 if smoke_test else 100


from gpytorch.priors import LogNormalPrior, NormalPrior, UniformPrior
# Use a positive constraint instead of usual GreaterThan(1e-4) so that LogNormal has support over full range.
likelihood = gpytorch.likelihoods.GaussianLikelihood(noise_constraint=gpytorch.constraints.Positive())
model = ExactGPModel(train_x, train_y, likelihood)

model.mean_module.register_prior("mean_prior", UniformPrior(-1, 1), "constant")
model.covar_module.base_kernel.register_prior("lengthscale_prior", UniformPrior(0.01, 0.5), "lengthscale")
model.covar_module.register_prior("outputscale_prior", UniformPrior(1, 2), "outputscale")
likelihood.register_prior("noise_prior", UniformPrior(0.01, 0.5), "noise")

mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

def pyro_model(x, y):
    with gpytorch.settings.fast_computations(False, False, False):
        sampled_model = model.pyro_sample_from_prior()
        output = sampled_model.likelihood(sampled_model(x))
        pyro.sample("obs", output, obs=y)
    return y

nuts_kernel = NUTS(pyro_model)
mcmc_run = MCMC(nuts_kernel, num_samples=num_samples, warmup_steps=warmup_steps, disable_progbar=smoke_test)
mcmc_run.run(train_x, train_y)
# Out:
# Warmup:   0%|                                                                                    | 0/200 [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\trace_messenger.py:174, in TraceHandler.__call__(self, *args, **kwargs)
#     173 try:
# --> 174     ret = self.fn(*args, **kwargs)
#     175 except (ValueError, RuntimeError) as e:
#
# Cell In[31], line 22, in pyro_model(x, y)
#      21 with gpytorch.settings.fast_computations(False, False, False):
# ---> 22     sampled_model = model.pyro_sample_from_prior()
#      23     output = sampled_model.likelihood(sampled_model(x))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:387, in Module.pyro_sample_from_prior(self)
#     386 new_module = self.to_pyro_random_module()
# --> 387 return _pyro_sample_from_prior(module=new_module, memo=None, prefix="")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:497, in _pyro_sample_from_prior(module, memo, prefix)
#     496     submodule_prefix = prefix + ("." if prefix else "") + mname
# --> 497     _pyro_sample_from_prior(module=module_, memo=memo, prefix=submodule_prefix)
#     499 return module
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:492, in _pyro_sample_from_prior(module, memo, prefix)
#     491 prior = prior.expand(closure(module).shape)
# --> 492 value = pyro.sample(prefix + ("." if prefix else "") + prior_name, prior)
#     493 setting_closure(module, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\primitives.py:163, in sample(name, fn, *args, **kwargs)
#     162 # apply the stack and return its return value
# --> 163 apply_stack(msg)
#     164 return msg["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\runtime.py:218, in apply_stack(initial_msg)
#     216         break
# --> 218 default_process_message(msg)
#     220 for frame in stack[-pointer:]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\runtime.py:179, in default_process_message(msg)
#     177     return msg
# --> 179 msg["value"] = msg["fn"](*msg["args"], **msg["kwargs"])
#     181 # after fn has been called, update msg to prevent it from being called again.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:363, in _forward_unimplemented(self, *input)
#     353 r"""Defines the computation performed at every call.
#     354
#     355 Should be overridden by all subclasses.
#    (...)
#     361     registered hooks while the latter silently ignores them.
#     362 """
# --> 363 raise NotImplementedError(f"Module [{type(self).__name__}] is missing the required \"forward\" function")
#
# NotImplementedError: Module [UniformPrior] is missing the required "forward" function
#
# The above exception was the direct cause of the following exception:
#
# NotImplementedError                       Traceback (most recent call last)
# Cell In[31], line 29
#      27 nuts_kernel = NUTS(pyro_model)
#      28 mcmc_run = MCMC(nuts_kernel, num_samples=num_samples, warmup_steps=warmup_steps)
# ---> 29 mcmc_run.run(train_x, train_y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\messenger.py:12, in _context_wrap(context, fn, *args, **kwargs)
#      10 def _context_wrap(context, fn, *args, **kwargs):
#      11     with context:
# ---> 12         return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\api.py:563, in MCMC.run(self, *args, **kwargs)
#     554 with optional(
#     555     pyro.validation_enabled(not self.disable_validation),
#     556     self.disable_validation is not None,
#    (...)
#     560     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     561     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     562     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 563     for x, chain_id in self.sampler.run(*args, **kwargs):
#     564         if num_samples[chain_id] == 0:
#     565             num_samples[chain_id] += 1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\api.py:223, in _UnarySampler.run(self, *args, **kwargs)
#     221 logger = initialize_logger(logger, "", progress_bar)
#     222 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 223 for sample in _gen_samples(
#     224     self.kernel,
#     225     self.warmup_steps,
#     226     self.num_samples,
#     227     hook_w_logging,
#     228     i if self.num_chains > 1 else None,
#     229     *args,
#     230     **kwargs
#     231 ):
#     232     yield sample, i  # sample, chain_id
#     233 self.kernel.cleanup()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\api.py:144, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     143 def _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs):
# --> 144     kernel.setup(warmup_steps, *args, **kwargs)
#     145     params = kernel.initial_params
#     146     save_params = getattr(kernel, "save_params", sorted(params))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\hmc.py:345, in HMC.setup(self, warmup_steps, *args, **kwargs)
#     343 self._warmup_steps = warmup_steps
#     344 if self.model is not None:
# --> 345     self._initialize_model_properties(args, kwargs)
#     346 if self.initial_params:
#     347     z = {k: v.detach() for k, v in self.initial_params.items()}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\hmc.py:279, in HMC._initialize_model_properties(self, model_args, model_kwargs)
#     278 def _initialize_model_properties(self, model_args, model_kwargs):
# --> 279     init_params, potential_fn, transforms, trace = initialize_model(
#     280         self.model,
#     281         model_args,
#     282         model_kwargs,
#     283         transforms=self.transforms,
#     284         max_plate_nesting=self._max_plate_nesting,
#     285         jit_compile=self._jit_compile,
#     286         jit_options=self._jit_options,
#     287         skip_jit_warnings=self._ignore_jit_warnings,
#     288         init_strategy=self._init_strategy,
#     289         initial_params=self._initial_params,
#     290     )
#     291     self.potential_fn = potential_fn
#     292     self.transforms = transforms
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\util.py:427, in initialize_model(model, model_args, model_kwargs, transforms, max_plate_nesting, jit_compile, jit_options, skip_jit_warnings, num_chains, init_strategy, initial_params)
#     425     automatic_transform_enabled = False
#     426 if max_plate_nesting is None:
# --> 427     max_plate_nesting = _guess_max_plate_nesting(model, model_args, model_kwargs)
#     428 # Wrap model in `poutine.enum` to enumerate over discrete latent sites.
#     429 # No-op if model does not have any discrete latents.
#     430 model = poutine.enum(
#     431     config_enumerate(model), first_available_dim=-1 - max_plate_nesting
#     432 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\infer\mcmc\util.py:251, in _guess_max_plate_nesting(model, args, kwargs)
#     245 """
#     246 Guesses max_plate_nesting by running the model once
#     247 without enumeration. This optimistically assumes static model
#     248 structure.
#     249 """
#     250 with poutine.block():
# --> 251     model_trace = poutine.trace(model).get_trace(*args, **kwargs)
#     252 sites = [site for site in model_trace.nodes.values() if site["type"] == "sample"]
#     254 dims = [
#     255     frame.dim
#     256     for site in sites
#     257     for frame in site["cond_indep_stack"]
#     258     if frame.vectorized
#     259 ]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\trace_messenger.py:198, in TraceHandler.get_trace(self, *args, **kwargs)
#     190 def get_trace(self, *args, **kwargs):
#     191     """
#     192     :returns: data structure
#     193     :rtype: pyro.poutine.Trace
#    (...)
#     196     Calls this poutine and returns its trace instead of the function's return value.
#     197     """
# --> 198     self(*args, **kwargs)
#     199     return self.msngr.get_trace()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\trace_messenger.py:180, in TraceHandler.__call__(self, *args, **kwargs)
#     178         exc = exc_type("{}\n{}".format(exc_value, shapes))
#     179         exc = exc.with_traceback(traceback)
# --> 180         raise exc from e
#     181     self.msngr.trace.add_node(
#     182         "_RETURN", name="_RETURN", type="return", value=ret
#     183     )
#     184 return ret
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\trace_messenger.py:174, in TraceHandler.__call__(self, *args, **kwargs)
#     170 self.msngr.trace.add_node(
#     171     "_INPUT", name="_INPUT", type="args", args=args, kwargs=kwargs
#     172 )
#     173 try:
# --> 174     ret = self.fn(*args, **kwargs)
#     175 except (ValueError, RuntimeError) as e:
#     176     exc_type, exc_value, traceback = sys.exc_info()
#
# Cell In[31], line 22, in pyro_model(x, y)
#      20 def pyro_model(x, y):
#      21     with gpytorch.settings.fast_computations(False, False, False):
# ---> 22         sampled_model = model.pyro_sample_from_prior()
#      23         output = sampled_model.likelihood(sampled_model(x))
#      24         pyro.sample("obs", output, obs=y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:387, in Module.pyro_sample_from_prior(self)
#     379 """
#     380 For each parameter in this Module and submodule that have defined priors, sample a value for that parameter
#     381 from its corresponding prior with a pyro.sample primitive and load the resulting value in to the parameter.
#    (...)
#     384 parameters of the model that have GPyTorch priors registered to them.
#     385 """
#     386 new_module = self.to_pyro_random_module()
# --> 387 return _pyro_sample_from_prior(module=new_module, memo=None, prefix="")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:497, in _pyro_sample_from_prior(module, memo, prefix)
#     495 for mname, module_ in module.named_children():
#     496     submodule_prefix = prefix + ("." if prefix else "") + mname
# --> 497     _pyro_sample_from_prior(module=module_, memo=memo, prefix=submodule_prefix)
#     499 return module
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gpytorch\module.py:492, in _pyro_sample_from_prior(module, memo, prefix)
#     490             memo.add(prior)
#     491             prior = prior.expand(closure(module).shape)
# --> 492             value = pyro.sample(prefix + ("." if prefix else "") + prior_name, prior)
#     493             setting_closure(module, value)
#     495 for mname, module_ in module.named_children():
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\primitives.py:163, in sample(name, fn, *args, **kwargs)
#     146 msg = {
#     147     "type": "sample",
#     148     "name": name,
#    (...)
#     160     "continuation": None,
#     161 }
#     162 # apply the stack and return its return value
# --> 163 apply_stack(msg)
#     164 return msg["value"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\runtime.py:218, in apply_stack(initial_msg)
#     215     if msg["stop"]:
#     216         break
# --> 218 default_process_message(msg)
#     220 for frame in stack[-pointer:]:
#     221     frame._postprocess_message(msg)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyro\poutine\runtime.py:179, in default_process_message(msg)
#     176     msg["done"] = True
#     177     return msg
# --> 179 msg["value"] = msg["fn"](*msg["args"], **msg["kwargs"])
#     181 # after fn has been called, update msg to prevent it from being called again.
#     182 msg["done"] = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:363, in _forward_unimplemented(self, *input)
#     352 def _forward_unimplemented(self, *input: Any) -> None:
#     353     r"""Defines the computation performed at every call.
#     354
#     355     Should be overridden by all subclasses.
#    (...)
#     361         registered hooks while the latter silently ignores them.
#     362     """
# --> 363     raise NotImplementedError(f"Module [{type(self).__name__}] is missing the required \"forward\" function")
#
# NotImplementedError: Module [UniformPrior] is missing the required "forward" function
# Trace Shapes:
#  Param Sites:
# Sample Sites:
