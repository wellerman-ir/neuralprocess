# %% [markdown]
# ## Training data
#
# A crucial property of CNPs is their flexibility at test time, as they can model
# a whole range of functions and narrow down their prediction as we condition on
# an increasing number of context observations. This behaviour is a result of the
# training regime of CNPs which is reflected in our datasets.
#
# ![](https://bit.ly/2O2Lq8c)
#
# Rather than training using observations from a single function as it is often
# the case in machine learning (for example value functions in reinforcement
# learning) we will use a dataset that <h6>consists of many different functions that
# share some underlying characteristics.</h6> This is visualized in the figure above.
# The example on the left corresponds to a classic training regime: we have a
# single underlying ground truth function (eg. our value function for an agent) in
# grey and at each learning iteration we are provided with a handful of examples from this
# function that we have visualized in different colours for batches of different
# iterations. On the right we show an example of a dataset that could be used for
# training neural processes. <h6>Instead of a single function, it consists of a large number of functions of a function-class</h6> that we are interested in modeling. At each iteration we randomly choose one from the dataset and provide some observations from that function for training. For the next iteration we put that function back and
# pick a new one from our dataset and use this new function to select the training
# data. <h6>This type of dataset ensures that our model can't overfit to a single
# function but rather learns a distribution over functions.</h6> This idea of a
# hierarchical dataset also lies at the core of current meta-learning methods.
# Examples of such datasets could be:
#
# *  Functions describing the evolution of temperature over time in different cities
# of the world.
# *  A dataset of functions generated by a motion capture sensor of different humans
#     walking.
# *   As in this particular example differents functions generated by a Gaussian process (GP)
#     with a specific kernel.
#
# <h6>We have chosen GPs for the data generation of this example because they
# constitute an easy way of sampling smooth curves that share some underlying
# characteristic (in this case the kernel).</h6> Other than for data generation of this
# particular example neural processes do not make use of kernels or GPs as they
# are implemented as neural networks.

# %%
# importing modules
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt
import pandas as pd 
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

# %%
# Get cpu, gpu or mps device for training.
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
df = pd.read_csv("AAPL_price.csv")
bs = 32
train_portion = 0.8 
print(df.shape)
# dataset length is dividable to batch size 
df_train = df[:int(df.shape[0]*train_portion//1)]
df_train = df_train[df_train.shape[0]%bs : ]
df_train = torch.FloatTensor(df_train.reset_index().values)
X_train = df_train[:,0]
y_train = df_train[:,1]




df_test = df[int(df.shape[0]*train_portion//1):]
df_test = torch.FloatTensor(df_test.reset_index().values)
X_test = df_test[:,0]
y_test = df_test[:,1]



print(df_train.dtype)
print(y_test.shape )
num_batches = int(df_train.shape[0]/bs)
# Out:
# (4139, 1)
# torch.float32
# torch.Size([828])

# %%
class AE(torch.nn.Module):
    def __init__(self):
        super().__init__()
         
        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(2 , 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 128),
        )
         
        self.decoder = torch.nn.Sequential(
            torch.nn.Linear(128, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 128),
            torch.nn.ReLU(),
            torch.nn.Linear(128, 2),
        )
 
    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

# %%
# Model Initialization
model = AE()
 
# Validation using MSE Loss function
loss_function = torch.nn.MSELoss()
 
# Using an Adam Optimizer with lr = 0.1
optimizer = torch.optim.Adam(model.parameters(),
                             lr = 1e-1,
                             weight_decay = 1e-8)

# %%
epochs = 5
outputs = []
losses = []
for epoch in range(epochs):
    for i in range(num_batches):
#         X_train_b, y_train_b = X_train[i*bs : (i+1)*bs], y_train[i*bs : (i+1)*bs]
        df_train_b = df_train[i*bs : (i+1)*bs]
        y_train_b = y_train[i*bs : (i+1)*bs]
        print(df_train_b.shape)

        # Compute prediction error
        pred = model(df_train_b)
        
        # Calculating the loss function
        loss = loss_function(pred, y_train_b)
       
        # The gradients are set to zero,
        # the gradient is computed and stored.
        # .step() performs parameter update
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
       
        # Storing the losses in a list for plotting
        losses.append(loss)
 
        if i % 10 == 0:
            print(f"epoch {epoch} , batch {i} ,  loss is : {loss}")
# Out:
# torch.Size([1, 2])
# epoch 0 , batch 0 ,  loss is : 16449.9296875
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 10 ,  loss is : 20226.55859375
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 20 ,  loss is : 7.551443099975586
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 30 ,  loss is : 42176.05859375
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 40 ,  loss is : 9.951522827148438
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 50 ,  loss is : 9.995168685913086
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 60 ,  loss is : 10.752273559570312
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 70 ,  loss is : 10.321407318115234
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 80 ,  loss is : 12.183958053588867
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 90 ,  loss is : 14.483182907104492
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 100 ,  loss is : 15.62664794921875
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 110 ,  loss is : 17.19075584411621
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 120 ,  loss is : 16.907625198364258
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 130 ,  loss is : 20.77621841430664
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 140 ,  loss is : 22.300357818603516
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 150 ,  loss is : 21.121295928955078
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 160 ,  loss is : 20.536874771118164
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 170 ,  loss is : 21.255123138427734
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 180 ,  loss is : 22.926864624023438
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 190 ,  loss is : 28.56544303894043
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 200 ,  loss is : 35.368133544921875
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 210 ,  loss is : 41.336082458496094
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 220 ,  loss is : 31.2034912109375
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 230 ,  loss is : 38.55393981933594
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 240 ,  loss is : 42.030670166015625
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 250 ,  loss is : 45.41059494018555
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 260 ,  loss is : 32.28575897216797
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 270 ,  loss is : 18.902374267578125
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 280 ,  loss is : 17.917102813720703
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 290 ,  loss is : 17.950843811035156
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 300 ,  loss is : 17.245101928710938
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 310 ,  loss is : 21.87104034423828
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 320 ,  loss is : 23.11979103088379
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 330 ,  loss is : 31.334583282470703
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 340 ,  loss is : 36.82317352294922
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 350 ,  loss is : 35.58341979980469
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 360 ,  loss is : 35.50196075439453
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 370 ,  loss is : 31.73923110961914
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 380 ,  loss is : 34.0999641418457
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 390 ,  loss is : 26.947772979736328
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 400 ,  loss is : 26.21630096435547
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 410 ,  loss is : 30.900054931640625
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 420 ,  loss is : 28.10403060913086
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 430 ,  loss is : 15.068680763244629
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 440 ,  loss is : 10.203224182128906
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 450 ,  loss is : 7.726938247680664
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 460 ,  loss is : 9.010952949523926
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 470 ,  loss is : 6.117440223693848
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 480 ,  loss is : 6.944415092468262
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 490 ,  loss is : 6.881742477416992
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 500 ,  loss is : 5.212703704833984
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 510 ,  loss is : 5.632352828979492
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 520 ,  loss is : 5.93296480178833
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 530 ,  loss is : 7.169100284576416
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 540 ,  loss is : 5.889643669128418
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 550 ,  loss is : 6.095733642578125
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 560 ,  loss is : 8.698907852172852
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 570 ,  loss is : 10.798114776611328
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 580 ,  loss is : 12.916769027709961
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 590 ,  loss is : 13.740161895751953
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 600 ,  loss is : 12.34506607055664
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch 610 ,  loss is : 17.855039596557617
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 0 , batch
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2840 ,  loss is : 0.6307247877120972
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2850 ,  loss is : 2.935523509979248
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2860 ,  loss is : 15.69544792175293
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2870 ,  loss is : 7.227475166320801
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2880 ,  loss is : 5.662253379821777
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2890 ,  loss is : 0.42598795890808105
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2900 ,  loss is : 0.002298549981787801
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2910 ,  loss is : 2.144968032836914
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2920 ,  loss is : 16.095035552978516
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2930 ,  loss is : 19.657819747924805
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2940 ,  loss is : 18.9322452545166
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2950 ,  loss is : 2.381282329559326
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2960 ,  loss is : 4.9564595222473145
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2970 ,  loss is : 2.577144145965576
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2980 ,  loss is : 0.004680835176259279
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 2990 ,  loss is : 46.66057205200195
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3000 ,  loss is : 56.093868255615234
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3010 ,  loss is : 65.07943725585938
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3020 ,  loss is : 40.39906311035156
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3030 ,  loss is : 16.880207061767578
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3040 ,  loss is : 0.7392763495445251
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3050 ,  loss is : 6.352921009063721
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3060 ,  loss is : 9.607034683227539
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3070 ,  loss is : 24.66158676147461
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3080 ,  loss is : 19.860944747924805
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3090 ,  loss is : 24.477474212646484
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3100 ,  loss is : 20.211204528808594
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3110 ,  loss is : 3.9390766620635986
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3120 ,  loss is : 19.54258918762207
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3130 ,  loss is : 0.1754688322544098
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3140 ,  loss is : 0.8769224882125854
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3150 ,  loss is : 6.417784690856934
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3160 ,  loss is : 10.218470573425293
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3170 ,  loss is : 0.008580037392675877
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3180 ,  loss is : 7.7728166580200195
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3190 ,  loss is : 5.855606555938721
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3200 ,  loss is : 12.670228958129883
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3210 ,  loss is : 6.100095748901367
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3220 ,  loss is : 23.757701873779297
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3230 ,  loss is : 42.88018035888672
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3240 ,  loss is : 60.53767395019531
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3250 ,  loss is : 41.64683532714844
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3260 ,  loss is : 39.71792221069336
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3270 ,  loss is : 68.7069091796875
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3280 ,  loss is : 122.26473999023438
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3290 ,  loss is : 121.18183898925781
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3300 ,  loss is : 80.48658752441406
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# torch.Size([1, 2])
# epoch 4 , batch 3310 ,  loss is : 44.40007019042969

# %%
def train(df_train, model, loss_fn, optimizer):
    
    y_train = df_train.Close
    X_train = df_train.index
    
    model.train()
#   model is ready for train 
    
    for i in range(num_batches):
        X_train_b, y_train_b = X_train[i*bs : (i+1)*bs].to(device), y_train[i*bs : (i+1)*bs].to(device)

        # Compute prediction error
        pred = model(X_train_b)
        loss = loss_fn(pred, y_train_b)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 10 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %%
def test(df , model, loss_fn):
    y = df.Close
    X = df.index
    model.eval()
    test_loss, correct = 0, 0
    
    with torch.no_grad():
        for X, y in df:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
epochs = 5
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth"

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth"))

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    x = x.to(device)
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')

# %% [markdown]
#
#           query: Array containing ((context_x, context_y), target_x) where:
#
#           context_x: Array of shape batch_size x num_context x 1
#           context_y: Array of shape batch_size x num_context x 1
#
#           target_x: Array of shape batch_size x num_target x 1
#           target_y: Array of shape batchsize x num_targets x 1.The ground truth y values of the target y.
#
#           num_total_points: Number of target points.
#
#     Returns:
#       log_p: The log_probability of the target_y given the predicted
#       distribution.
#       mu: The mean of the predicted distribution.
#       sigma: The variance of the predicted distribution.
#     """

# %% [markdown]
# ## Data generator
#
# In the following section we provide the code for generating our training and
# testing sets using a GP to generate a dataset of functions. As we will explain
# later, CNPs use two subset of points at every iteration: one to serve as the
# context, and the other as targets. In practise we found that including the
# context points as targets together with some additional new points helped during
# training. Our data generator divides the generated data into these two groups
# and provides it in the correct format.<br>
#
# <h6>
# CNPRegressionDescription ::  iput of CNP<br>
# GPCurveReader :: data sampled from GP at each iteration
#     </h6>

# %%
df = pd.DataFrame(columns=["name" , "age" ,"text"])
for i in range(10):
    df.loc[i] = [f"user{i}" , i**2 , "there is sth in the middle"]
df
# Out:
#     name  age                        text
# 0  user0    0  there is sth in the middle
# 1  user1    1  there is sth in the middle
# 2  user2    4  there is sth in the middle
# 3  user3    9  there is sth in the middle
# 4  user4   16  there is sth in the middle
# 5  user5   25  there is sth in the middle
# 6  user6   36  there is sth in the middle
# 7  user7   49  there is sth in the middle
# 8  user8   64  there is sth in the middle
# 9  user9   81  there is sth in the middle

# %%
df.shape
# Out:
# (10, 3)

# %% [markdown]
# ### concat note
# #### [3,10,5]
# ####  [3,10,5]
# <br>
# axis= 0 means [6,10,5] <br>
# axis= 1 means [3,20,5] <br>
# axis= 2 means [3,10,10]
#
#
# ### Linear = dense = fullyconnected

# %%
bs = 10 
tensor = tf.zeros([bs,2,5])
context_x = tf.zeros([bs , 100 , 1])
context_y = tf.zeros([bs , 100 , 1])
encoder_input = tf.concat([context_x, context_y], axis=-1)
encoder_input.shape.as_list()
# Out:
# [10, 100, 2]

# %% [markdown]
# ## Encoder
#
# The encoder **e** is shared between all the context points and consists of an
# MLP with a handful of layers. For this experiment four layers are enough [128,128,128,128] </br>, but we
# can still change the number and size of the layers when we build the graph later
# on via the variable **`encoder_output_sizes`**. Each of the context pairs **(x,
# y)<sub>i</sub>** results in an individual representation **r<sub>i</sub>** after
# encoding. These representations are then combined across context points to form
# a single representation **r** using the aggregator **a**.
#
# In this implementation we have included the aggregator **a** in the encoder as
# we are only taking the mean across all points. The representation **r** produced
# by the aggregator contains the information about the underlying unknown function
# **f** that is provided by all the context points.

# %%
class DeterministicEncoder(object):
  """The Encoder."""

  def __init__(self, output_sizes):
    """CNP encoder."""
    self._output_sizes = output_sizes

    
  def __call__(self, context_x, context_y, num_context_points):

    # Concatenate x and y along the filter axes
    encoder_input = tf.concat([context_x, context_y], axis=-1)

    
    
    # Get the shapes of the input and reshape to parallelise across observations
    batch_size, _, filter_size = encoder_input.shape.as_list()
    hidden = tf.reshape(encoder_input, (batch_size * num_context_points, -1))
    hidden.set_shape((None, filter_size))

    # Pass through MLP
    # , reuse=tf.compact.v1.AUTO_REUSE
    with tf.compat.v1.variable_scope("encoder"):
      for i, size in enumerate(self._output_sizes[:-1]):
        hidden = tf.nn.relu(
            tf.compat.v1.layers.dense(hidden, size, name="Encoder_layer_{}".format(i)))

      # Last layer without a ReLu
      hidden = tf.compat.v1.layers.dense(
          hidden, self._output_sizes[-1], name="Encoder_layer_{}".format(i + 1))

    # Bring back into original shape
    hidden = tf.reshape(hidden, (batch_size, num_context_points, size))

    # Aggregator: take the mean over all points
    representation = tf.reduce_mean(hidden, axis=1)

    return representation

# %% [markdown]
# ## Decoder
#
# Once we have obtained our representation **r** we concatenate it with each of
# the targets **x<sub>t</sub>** and pass it through the decoder **d**. As with the
# encoder **e**, the decoder **d** is shared between all the target points and
# consists of a small MLP with layer sizes defined in **`decoder_output_sizes`**.<br>
# [128,128,2] <br>
# The decoder outputs a mean **&mu;<sub>t</sub>** and a variance
# **&sigma;<sub>t</sub>** for each of the targets **x<sub>t</sub>**. To train our
# CNP we use the log likelihood of the ground truth value **y<sub>t</sub>** under
# a Gaussian parametrized by these predicted **&mu;<sub>t</sub>** and
# **&sigma;<sub>t</sub>**.
#
# In this implementation we clip the variance **&sigma;<sub>t</sub>** at 0.1 to
# avoid collapsing.

# %%
class DeterministicDecoder(object):
  """The Decoder."""

  def __init__(self, output_sizes):
    """CNP decoder.

    Args:
      output_sizes: An iterable containing the output sizes of the decoder MLP 
          as defined in `basic.Linear`.
    """
    self._output_sizes = output_sizes

  def __call__(self, representation, target_x, num_total_points):
    """Decodes the individual targets.

    Args:
      representation: The encoded representation of the context
      target_x: The x locations for the target query
      num_total_points: The number of target points.

    Returns:
      dist: A multivariate Gaussian over the target points.
      mu: The mean of the multivariate Gaussian.
      sigma: The standard deviation of the multivariate Gaussian.
    """

    # Concatenate the representation and the target_x
    representation = tf.tile(
        tf.expand_dims(representation, axis=1), [1, num_total_points, 1])
    input = tf.concat([representation, target_x], axis=-1)

    # Get the shapes of the input and reshape to parallelise across observations
    batch_size, _, filter_size = input.shape.as_list()
    hidden = tf.reshape(input, (batch_size * num_total_points, -1))
    hidden.set_shape((None, filter_size))

    # Pass through MLP
    with tf.compat.v1.variable_scope("decoder"):
      for i, size in enumerate(self._output_sizes[:-1]):
        hidden = tf.nn.relu(
            tf.compat.v1.layers.dense(hidden, size, name="Decoder_layer_{}".format(i)))

      # Last layer without a ReLu
      hidden = tf.compat.v1.layers.dense(
          hidden, self._output_sizes[-1], name="Decoder_layer_{}".format(i + 1))

    # Bring back into original shape
    hidden = tf.reshape(hidden, (batch_size, num_total_points, -1))

    # Get the mean an the variance
    mu, log_sigma = tf.split(hidden, 2, axis=-1)

    # Bound the variance
    sigma = 0.1 + 0.9 * tf.nn.softplus(log_sigma)

    # Get the distribution
#     dist = tf.contrib.distributions.MultivariateNormalDiag(
#         loc=mu, scale_diag=sigma)
#     dist = tf.compat.v1.distributions.MultivariateNormalDiag(
#         loc=mu, scale_diag=sigma)
    dist = tfp.distributions.MultivariateNormalDiag(
        loc=mu, scale_diag=sigma)
    

    return dist, mu, sigma

# %% [markdown]
# ## Model
#
# Now that the main building blocks (encoder, aggregator and decoder) of the CNP
# are defined we can put everything together into one model. Fundamentally this
# model only needs to include two main methods: 1. A method that returns the log
# likelihood of the targets' ground truth values under the predicted
# distribution.This method will be called during training as our loss function. 2.
# Another method that returns the predicted mean and variance at the target
# locations in order to evaluate or query the CNP at test time. This second method
# needs to be defined separately as, unlike the method above, it should not depend
# on the ground truth target values.

# %%
class DeterministicModel(object):
  """The CNP model."""

  def __init__(self, encoder_output_sizes, decoder_output_sizes):
   
    self._encoder = DeterministicEncoder(encoder_output_sizes)
    self._decoder = DeterministicDecoder(decoder_output_sizes)

  def __call__(self, query, num_total_points, num_contexts, target_y=None):

    (context_x, context_y), target_x = query

    # Pass query through the encoder and the decoder
    representation = self._encoder(context_x, context_y, num_contexts)
    dist, mu, sigma = self._decoder(representation, target_x, num_total_points)

    # If we want to calculate the log_prob for training we will make use of the
    # target_y. At test time the target_y is not available so we return None
    if target_y is not None:
      log_p = dist.log_prob(target_y)
    else:
      log_p = None

    return log_p, mu, sigma

# %%
# Out:
#       Unnamed: 0       Date       Close
# 4129        4129  5/30/2023  177.300003
# 4130        4130  5/31/2023  177.250000
# 4131        4131   6/1/2023  180.089996
# 4132        4132   6/2/2023  180.949997
# 4133        4133   6/5/2023  179.580002
# 4134        4134   6/6/2023  179.210007
# 4135        4135   6/7/2023  177.820007
# 4136        4136   6/8/2023  180.570007
# 4137        4137   6/9/2023  180.960007
# 4138        4138  6/12/2023  183.789993

# %% [markdown]
# ### RUN

# %%
encoder_output_sizes = [128, 128, 128, 128]
decoder_output_sizes = [128, 128, 2]
model = DeterministicModel(encoder_output_sizes, decoder_output_sizes)



log_prob, _, _ = model(data_train.query, data_train.num_total_points,
                       data_train.num_context_points, data_train.target_y)
loss = -tf.reduce_mean(log_prob)



# _, mu, sigma = model(data_test.query, data_test.num_total_points,
#                      data_test.num_context_points)





# # Set up the optimizer and train step
# optimizer = tf.train.AdamOptimizer(1e-4)
# train_step = optimizer.minimize(loss)
# init = tf.initialize_all_variables()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 7
#       2 decoder_output_sizes = [128, 128, 2]
#       3 model = DeterministicModel(encoder_output_sizes, decoder_output_sizes)
# ----> 7 log_prob, _, _ = model(data_train.query, data_train.num_total_points,
#       8                        data_train.num_context_points, data_train.target_y)
#       9 loss = -tf.reduce_mean(log_prob)
#      13 # _, mu, sigma = model(data_test.query, data_test.num_total_points,
#      14 #                      data_test.num_context_points)
#      15
#    (...)
#      22 # train_step = optimizer.minimize(loss)
#      23 # init = tf.initialize_all_variables()
#
# AttributeError: 'int' object has no attribute 'query'

# %%
with tf.Session() as sess:
  sess.run(init)

  for it in range(TRAINING_ITERATIONS):
    sess.run([train_step])

    # Plot the predictions in `PLOT_AFTER` intervals
    if it % PLOT_AFTER == 0:
      loss_value, pred_y, var, target_y, whole_query = sess.run(
          [loss, mu, sigma, data_test.target_y, data_test.query])

      (context_x, context_y), target_x = whole_query
      print('Iteration: {}, loss: {}'.format(it, loss_value))

      # Plot the prediction and the context
      plot_functions(target_x, target_y, context_x, context_y, pred_y, var)
